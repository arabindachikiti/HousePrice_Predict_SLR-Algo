# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
HousePrice_dataset= pd.read_csv(r'F:\Data science\April Month\21-04-2025\21st- SLR\SLR - House price prediction\House_data.csv')

# %%
HousePrice_dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
space=HousePrice_dataset['sqft_living'].values
price=HousePrice_dataset['price'].values

# %%
x=np.array(space).reshape(-1,1)
y=np.array(price).reshape(-1,1)
print(x.shape)
print(y.shape)
# Out:
# (21613, 1)
# (21613, 1)

# %% [markdown]
# Spliting the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %% [markdown]
# Filling Simple Linear Regression to the Traing set

# %%
pip install sklearn.linear_model
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sklearn.linear_model (from versions: none)
# ERROR: No matching distribution found for sklearn.linear_model

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Predicting the prices

# %%
predict=regressor.predict(x_test)

# %% [markdown]
# Visualization traing set result

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('House Price Prediction')
plt.xlabel('space')
plt.ylabel('price')
plt.show()

# %% [markdown]
# Visualization of Test result

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train) ,color='blue')
plt.title('House Price Prediction')
plt.xlabel('space') 
plt.ylabel('price')
plt.show()

# %% [markdown]
# Slope and Coficient

# %%
m_slope=regressor.coef_
print(m_slope)
c_intercept=regressor.intercept_
print(c_intercept)
# Out:
# [[273.97842513]]
# [-29315.4178225]

# %% [markdown]
# House price predition

# %%
house_price_predition=m_slope*1100+c_intercept
print(house_price_predition)
# Out:
# [[272060.84982543]]

# %%
#Bias
bias=regressor.score(x_train,y_train)
print(bias)
# Out:
# 0.48841971182453403

# %%
#Variance
variance=regressor.score(x_test,y_test)
print(variance)
# Out:
# 0.5000521542544756

# %%
import pickle
filename='HousePrice_Linear_regression_model_pkl'
with open(filename,'wb') as file:
    pickle.dump(regressor, file)
    
print('model has been created and store in HousePrice_Linear_regression_model_pkl')

import os
os.getcwd()
# Out:
# model has been created and store in HousePrice_Linear_regression_model_pkl
# 'c:\\Users\\Arabinda\\VS CODE\\Machine Learning\\House Price Predition'
